# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\mmanasanjani\Desktop\Extra\MK\HAI\course files\diabetes.csv')

# %%
print(df.head())
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# *   Pregnancies: Number of previous pregnancies
# *   Glucose: Plagma glucose concentration
#
# *   BloodPressure: Diastolic blood pressure
# *   SkinThickess: Skin fold thickness measured from the triceps
#
#
# *   Insulin: Blood serum insulin concentration
# *   BMI: Body Mass Index
#
# *   DiabetesPedigreeFunction: A summerized score that indicates the genetic predisposition of the patient for diabetes, as extrapolated from the patient's family record for diabetes
# *   Age: Age in years
#
#
# *   Outcome: The target variable we are trying to predict , 1 for patients that developed diabetes within 5 years of the initial measurement and 0 otherwise

# %%
from matplotlib import pyplot as plt
df.hist()
# Out:
# array([[<Axes: title={'center': 'Pregnancies'}>,
#         <Axes: title={'center': 'Glucose'}>,
#         <Axes: title={'center': 'BloodPressure'}>],
#        [<Axes: title={'center': 'SkinThickness'}>,
#         <Axes: title={'center': 'Insulin'}>,
#         <Axes: title={'center': 'BMI'}>],
#        [<Axes: title={'center': 'DiabetesPedigreeFunction'}>,
#         <Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Outcome'}>]], dtype=object)

# %%
plt.show()

# %%
import seaborn as sns
# create a subplot of 3x3
plt.subplots(3,3,figsize=(15,15))
#plot a density plot for each variable
# Plot a density plot for each variable
for idx, col in enumerate(df.columns):
    ax = plt.subplot(3,3,idx+1)
    ax.yaxis.set_ticklabels([])
    sns.distplot(df.loc[df.Outcome == 0][col], hist=False, axlabel= False, kde_kws={'linestyle':'-', 'color':'green', 'label':"No Diabetes"})
    sns.distplot(df.loc[df.Outcome == 1][col], hist=False, axlabel= False, kde_kws={'linestyle':'--', 'color':'red', 'label':"Diabetes"})
    ax.set_title(col)
#Hide the 9th subplot (bottom right since there are only 8 plots)
plt.subplot(3,3,9).set_visible(False)

plt.show()
# Out:
# C:\Users\mmanasanjani\AppData\Local\Temp\ipykernel_38624\3176794950.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.loc[df.Outcome == 0][col], hist=False, axlabel= False, kde_kws={'linestyle':'-', 'color':'green', 'label':"No Diabetes"})
# C:\Users\mmanasanjani\AppData\Local\Temp\ipykernel_38624\3176794950.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.loc[df.Outcome == 1][col], hist=False, axlabel= False, kde_kws={'linestyle':'--', 'color':'red', 'label':"Diabetes"})
# C:\Users\mmanasanjani\AppData\Local\Temp\ipykernel_38624\3176794950.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.loc[df.Outcome == 0][col], hist=False, axlabel= False, kde_kws={'linestyle':'-', 'color':'green', 'label':"No Diabetes"})
# C:\Users\mmanasanjani\AppData\Local\Temp\ipykernel_38624\3176794950.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.loc[df.Outcome == 1][col], hist=False, axlabel= False, kde_kws={'linestyle':'--', 'color':'red', 'label':"Diabetes"})
# C:\Users\mmanasanjani\AppData\Local\Temp\ipykernel_38624\3176794950.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.loc[df.Outcome == 0][col], hist=False, axlabel= False, kde_kws={'linestyle':'-', 'color':'green', 'label':"No Diabetes"})
# C:\Users\mmanasanjani\AppData\Local\Temp\ipykernel_38624\3176794950.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.loc[df.Outcome == 1][col], hist=False, axlabel= False, kde_kws={'linestyle':'--', 'color':'red', 'label':"Diabetes"})
# C:\Users\mmanasanjani\AppData\Local\Temp\ipykernel_38624\3176794950.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.loc[df.Outcome == 0][col], hist=False, axlabel= False, kde_kws={'linestyle':'-', 'color':'green', 'label':"No Diabetes"})
# C:\Users\mmanasanjani\AppData\Local\Temp\ipykernel_38624\3176794950.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.loc[df.Outcome == 1][col], hist=False, axlabel= False, kde_kws={'linestyle':'--', 'color':'red', 'label':"Diabetes"})
# C:\Users\mmanasanjani\AppData\Local\Temp\ipykernel_38624\3176794950.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.loc[df.Outcome == 0][col], hist=False, axlabel= False, kde_kws={'linestyle':'-', 'color':'green', 'label':"No Diabetes"})
# C:\Users\mmanasanjani\AppData\Local\Temp\ipykernel_38624\3176794950.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.loc[df.Outcome == 1][col], hist=False, axlabel= False, kde_kws={'linestyle':'--', 'color':'red', 'label':"Diabetes"})
# C:\Users\mmanasanjani\AppData\Local\Temp\ipykernel_38624\3176794950.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.loc[df.Outcome == 0][col], hist=False, axlabel= False, kde_kws={'linestyle':'-', 'color':'green', 'label':"No Diabetes"})
# C:\Users\mmanasanjani\AppData\Local\Temp\ipykernel_38624\3176794950.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.loc[df.Outcome == 1][col], hist=False, axlabel= False, kde_kws={'linestyle':'--', 'color':'red', 'label':"Diabetes"})
# C:\Users\mmanasanjani\AppData\Local\Temp\ipykernel_38624\3176794950.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.loc[df.Outcome == 0][col], hist=False, axlabel= False, kde_kws={'linestyle':'-', 'color':'green', 'label':"No Diabetes"})
# C:\Users\mmanasanjani\AppData\Local\Temp\ipykernel_38624\3176794950.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.loc[df.Outcome == 1][col], hist=False, axlabel= False, kde_kws={'linestyle':'--', 'color':'red', 'label':"Diabetes"})
# C:\Users\mmanasanjani\AppData\Local\Temp\ipykernel_38624\3176794950.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.loc[df.Outcome == 0][col], hist=False, axlabel= False, kde_kws={'linestyle':'-', 'color':'green', 'label':"No Diabetes"})
# C:\Users\mmanasanjani\AppData\Local\Temp\ipykernel_38624\3176794950.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.loc[df.Outcome == 1][col], hist=False, axlabel= False, kde_kws={'linestyle':'--', 'color':'red', 'label':"Diabetes"})
# C:\Users\mmanasanjani\AppData\Local\Temp\ipykernel_38624\3176794950.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.loc[df.Outcome == 0][col], hist=False, axlabel= False, kde_kws={'linestyle':'-', 'color':'green', 'label':"No Diabetes"})
# C:\Users\mmanasanjani\AppData\Local\anaconda3\Lib\site-packages\seaborn\distributions.py:2511: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# C:\Users\mmanasanjani\AppData\Local\Temp\ipykernel_38624\3176794950.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.loc[df.Outcome == 1][col], hist=False, axlabel= False, kde_kws={'linestyle':'--', 'color':'red', 'label':"Diabetes"})
# C:\Users\mmanasanjani\AppData\Local\anaconda3\Lib\site-packages\seaborn\distributions.py:2511: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)

# %%
print(df.isnull().any())
# Out:
# Pregnancies                 False
# Glucose                     False
# BloodPressure               False
# SkinThickness               False
# Insulin                     False
# BMI                         False
# DiabetesPedigreeFunction    False
# Age                         False
# Outcome                     False
# dtype: bool

# %%
print(df.describe())
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
print("Number of rows with 0 values for each variable")
for col in df.columns:
  missing_rows = df.loc[df[col]==0].shape[0]

  print(col + ": "+str(missing_rows))
# Out:
# Number of rows with 0 values for each variable
# Pregnancies: 111
# Glucose: 5
# BloodPressure: 35
# SkinThickness: 227
# Insulin: 374
# BMI: 11
# DiabetesPedigreeFunction: 0
# Age: 0
# Outcome: 500

# %%
#Replace 0 value with NaN
import numpy as np
df['Glucose'] = df['Glucose'].replace(0,np.nan)
df['BloodPressure'] = df['BloodPressure'].replace(0,np.nan)
df['SkinThickness'] = df['SkinThickness'].replace(0,np.nan)
df['Insulin'] = df['Insulin'].replace(0,np.nan)

df['BMI'] = df['BMI'].replace(0,np.nan)

# %%
print("Number of rows with 0 values for each variable")
for col in df.columns:
  missing_rows = df.loc[df[col]==0].shape[0]

  print(col + ": "+str(missing_rows))
# Out:
# Number of rows with 0 values for each variable
# Pregnancies: 111
# Glucose: 0
# BloodPressure: 0
# SkinThickness: 0
# Insulin: 0
# BMI: 0
# DiabetesPedigreeFunction: 0
# Age: 0
# Outcome: 500

# %%
# Replace Nan values with the mean of the non-missing values by using fillna()
df['Glucose'] = df['Glucose'].fillna(df['Glucose'].mean())
df['BloodPressure'] = df['BloodPressure'].fillna(df['BloodPressure'].mean())
df['SkinThickness'] = df['SkinThickness'].fillna(df['SkinThickness'].mean())
df['Insulin'] = df['Insulin'].fillna(df['Insulin'].mean())

df['BMI'] = df['BMI'].fillna(df['BMI'].mean())

# %%
from sklearn import preprocessing
df_scaled = preprocessing.scale(df)
df_scaled = pd.DataFrame(df_scaled,columns=df.columns)
df_scaled['Outcome'] = df['Outcome']
df = df_scaled
print(df.describe().loc[['mean','std','max'],].round(2).abs())
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# mean         0.00     0.00            0.0           0.00     0.00  0.00
# std          1.00     1.00            1.0           1.00     1.00  1.00
# max          3.91     2.54            4.1           7.95     8.13  5.04
#
#       DiabetesPedigreeFunction   Age  Outcome
# mean                      0.00  0.00     0.35
# std                       1.00  1.00     0.48
# max                       5.88  4.06     1.00

# %%
from sklearn.model_selection import train_test_split
X = df.loc[:, df.columns != 'Outcome']
y = df.loc[:, 'Outcome']
# Split the data into training set(80%) and the testing set(20%)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
# Make a second split to create the final training set and the validation set
X_train, X_val, y_train, y_val = train_test_split(X_train,y_train,test_size = 0.2)

# %%
from keras.models import Sequential
model = Sequential()
# Out:
# WARNING:tensorflow:From C:\Users\mmanasanjani\AppData\Local\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\mmanasanjani\AppData\Local\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
from keras.layers import Dense # Add the first Hidden layer
model.add(Dense(32, activation='relu', input_dim=8))
model.add(Dense(16, activation='relu'))# Add the second hidden layer
model.add(Dense(1, activation='sigmoid'))

# %%
# compile the model
model.compile(optimizer='adam', loss='binary_crossentropy',metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\mmanasanjani\AppData\Local\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
#Train the model for 200 epochs
model.fit(X_train,y_train,epochs=200)
# Out:
# Epoch 1/200
# WARNING:tensorflow:From C:\Users\mmanasanjani\AppData\Local\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\mmanasanjani\AppData\Local\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 16/16 [==============================] - 2s 6ms/step - loss: 0.7219 - accuracy: 0.4705
# Epoch 2/200
# 16/16 [==============================] - 0s 6ms/step - loss: 0.6576 - accuracy: 0.6538
# Epoch 3/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6128 - accuracy: 0.7169
# Epoch 4/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5771 - accuracy: 0.7291
# Epoch 5/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5440 - accuracy: 0.7312
# Epoch 6/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5185 - accuracy: 0.7413
# Epoch 7/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5007 - accuracy: 0.7454
# Epoch 8/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4879 - accuracy: 0.7495
# Epoch 9/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4777 - accuracy: 0.7495
# Epoch 10/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4707 - accuracy: 0.7617
# Epoch 11/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4648 - accuracy: 0.7699
# Epoch 12/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4598 - accuracy: 0.7800
# Epoch 13/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4561 - accuracy: 0.7800
# Epoch 14/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4521 - accuracy: 0.7780
# Epoch 15/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4495 - accuracy: 0.7841
# Epoch 16/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4463 - accuracy: 0.7882
# Epoch 17/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4436 - accuracy: 0.7821
# Epoch 18/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4418 - accuracy: 0.7821
# Epoch 19/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4389 - accuracy: 0.7882
# Epoch 20/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4377 - accuracy: 0.7902
# Epoch 21/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4349 - accuracy: 0.7923
# Epoch 22/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4324 - accuracy: 0.7882
# Epoch 23/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4308 - accuracy: 0.7882
# Epoch 24/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4284 - accuracy: 0.7963
# Epoch 25/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4266 - accuracy: 0.7963
# Epoch 26/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4249 - accuracy: 0.7963
# Epoch 27/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4239 - accuracy: 0.7984
# Epoch 28/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4210 - accuracy: 0.7923
# Epoch 29/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4193 - accuracy: 0.7963
# Epoch 30/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4174 - accuracy: 0.8024
# Epoch 31/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4168 - accuracy: 0.7984
# Epoch 32/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4143 - accuracy: 0.8024
# Epoch 33/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4128 - accuracy: 0.8004
# Epoch 34/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4111 - accuracy: 0.8065
# Epoch 35/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4092 - accuracy: 0.8065
# Epoch 36/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4076 - accuracy: 0.8065
# Epoch 37/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4061 - accuracy: 0.8086
# Epoch 38/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4053 - accuracy: 0.8086
# Epoch 39/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4031 - accuracy: 0.8065
# Epoch 40/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4016 - accuracy: 0.8065
# Epoch 41/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4008 - accuracy: 0.8126
# Epoch 42/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3988 - accuracy: 0.8086
# Epoch 43/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3976 - accuracy: 0.8106
# Epoch 44/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3960 - accuracy: 0.8086
# Epoch 45/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3949 - accuracy: 0.8106
# Epoch 46/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3942 - accuracy: 0.8065
# Epoch 47/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3928 - accuracy: 0.8106
# Epoch 48/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3910 - accuracy: 0.8086
# Epoch 49/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3894 - accuracy: 0.8086
# Epoch 50/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3881 - accuracy: 0.8045
# Epoch 51/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3867 - accuracy: 0.8126
# Epoch 52/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3853 - accuracy: 0.8126
# Epoch 53/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3830 - accuracy: 0.8167
# Epoch 54/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3822 - accuracy: 0.8187
# Epoch 55/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3804 - accuracy: 0.8248
# Epoch 56/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3791 - accuracy: 0.8208
# Epoch 57/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3776 - accuracy: 0.8167
# Epoch 58/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3768 - accuracy: 0.8187
# Epoch 59/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3751 - accuracy: 0.8289
# Epoch 60/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3738 - accuracy: 0.8289
# Epoch 61/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3724 - accuracy: 0.8269
# Epoch 62/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3720 - accuracy: 0.8289
# Epoch 63/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3704 - accuracy: 0.8310
# Epoch 64/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3688 - accuracy: 0.8289
# Epoch 65/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3697 - accuracy: 0.8371
# Epoch 66/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3658 - accuracy: 0.8330
# Epoch 67/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3683 - accuracy: 0.8330
# Epoch 68/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3646 - accuracy: 0.8330
# Epoch 69/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3638 - accuracy: 0.8228
# Epoch 70/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3627 - accuracy: 0.8411
# Epoch 71/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3593 - accuracy: 0.8391
# Epoch 72/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3596 - accuracy: 0.8411
# Epoch 73/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3582 - accuracy: 0.8411
# Epoch 74/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3567 - accuracy: 0.8411
# Epoch 75/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3564 - accuracy: 0.8330
# Epoch 76/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3555 - accuracy: 0.8391
# Epoch 77/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3539 - accuracy: 0.8411
# Epoch 78/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3536 - accuracy: 0.8330
# Epoch 79/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3505 - accuracy: 0.8391
# Epoch 80/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3507 - accuracy: 0.8391
# Epoch 81/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3491 - accuracy: 0.8452
# Epoch 82/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3472 - accuracy: 0.8452
# Epoch 83/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3452 - accuracy: 0.8473
# Epoch 84/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3456 - accuracy: 0.8513
# Epoch 85/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3439 - accuracy: 0.8473
# Epoch 86/200
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3427 - accuracy: 0.8452
# Epoch 87/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3406 - accuracy: 0.8452
# Epoch 88/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3419 - accuracy: 0.8493
# Epoch 89/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3394 - accuracy: 0.8452
# Epoch 90/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3390 - accuracy: 0.8452
# Epoch 91/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3373 - accuracy: 0.8473
# Epoch 92/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3364 - accuracy: 0.8432
# Epoch 93/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3346 - accuracy: 0.8534
# Epoch 94/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3341 - accuracy: 0.8473
# Epoch 95/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3340 - accuracy: 0.8473
# Epoch 96/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3316 - accuracy: 0.8452
# Epoch 97/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3300 - accuracy: 0.8493
# Epoch 98/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3294 - accuracy: 0.8554
# Epoch 99/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3285 - accuracy: 0.8493
# Epoch 100/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3266 - accuracy: 0.8452
# Epoch 101/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3267 - accuracy: 0.8493
# Epoch 102/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3248 - accuracy: 0.8534
# Epoch 103/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3233 - accuracy: 0.8513
# Epoch 104/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3232 - accuracy: 0.8534
# Epoch 105/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3214 - accuracy: 0.8513
# Epoch 106/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3213 - accuracy: 0.8473
# Epoch 107/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3212 - accuracy: 0.8513
# Epoch 108/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3179 - accuracy: 0.8513
# Epoch 109/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3198 - accuracy: 0.8493
# Epoch 110/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3201 - accuracy: 0.8554
# Epoch 111/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3152 - accuracy: 0.8513
# Epoch 112/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3150 - accuracy: 0.8513
# Epoch 113/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3141 - accuracy: 0.8554
# Epoch 114/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3128 - accuracy: 0.8554
# Epoch 115/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3112 - accuracy: 0.8554
# Epoch 116/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3113 - accuracy: 0.8595
# Epoch 117/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3138 - accuracy: 0.8554
# Epoch 118/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3086 - accuracy: 0.8554
# Epoch 119/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3079 - accuracy: 0.8574
# Epoch 120/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3054 - accuracy: 0.8574
# Epoch 121/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3047 - accuracy: 0.8595
# Epoch 122/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3036 - accuracy: 0.8656
# Epoch 123/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3024 - accuracy: 0.8615
# Epoch 124/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3025 - accuracy: 0.8595
# Epoch 125/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3021 - accuracy: 0.8554
# Epoch 126/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3004 - accuracy: 0.8595
# Epoch 127/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3010 - accuracy: 0.8595
# Epoch 128/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2976 - accuracy: 0.8595
# Epoch 129/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2970 - accuracy: 0.8595
# Epoch 130/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2952 - accuracy: 0.8656
# Epoch 131/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2956 - accuracy: 0.8595
# Epoch 132/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2951 - accuracy: 0.8595
# Epoch 133/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2925 - accuracy: 0.8615
# Epoch 134/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2922 - accuracy: 0.8635
# Epoch 135/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2903 - accuracy: 0.8615
# Epoch 136/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2906 - accuracy: 0.8615
# Epoch 137/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2890 - accuracy: 0.8656
# Epoch 138/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2892 - accuracy: 0.8656
# Epoch 139/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2887 - accuracy: 0.8635
# Epoch 140/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2857 - accuracy: 0.8656
# Epoch 141/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2865 - accuracy: 0.8656
# Epoch 142/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2839 - accuracy: 0.8676
# Epoch 143/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2841 - accuracy: 0.8656
# Epoch 144/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2835 - accuracy: 0.8697
# Epoch 145/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2831 - accuracy: 0.8656
# Epoch 146/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2806 - accuracy: 0.8635
# Epoch 147/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2801 - accuracy: 0.8737
# Epoch 148/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2790 - accuracy: 0.8697
# Epoch 149/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2780 - accuracy: 0.8676
# Epoch 150/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2771 - accuracy: 0.8737
# Epoch 151/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2767 - accuracy: 0.8758
# Epoch 152/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2766 - accuracy: 0.8656
# Epoch 153/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2732 - accuracy: 0.8758
# Epoch 154/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2748 - accuracy: 0.8737
# Epoch 155/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2727 - accuracy: 0.8697
# Epoch 156/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2725 - accuracy: 0.8717
# Epoch 157/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2721 - accuracy: 0.8798
# Epoch 158/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2698 - accuracy: 0.8778
# Epoch 159/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2679 - accuracy: 0.8778
# Epoch 160/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2675 - accuracy: 0.8758
# Epoch 161/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2667 - accuracy: 0.8737
# Epoch 162/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2653 - accuracy: 0.8778
# Epoch 163/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2660 - accuracy: 0.8778
# Epoch 164/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2632 - accuracy: 0.8778
# Epoch 165/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2617 - accuracy: 0.8839
# Epoch 166/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2622 - accuracy: 0.8798
# Epoch 167/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2610 - accuracy: 0.8839
# Epoch 168/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2600 - accuracy: 0.8839
# Epoch 169/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2591 - accuracy: 0.8839
# Epoch 170/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2581 - accuracy: 0.8798
# Epoch 171/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2576 - accuracy: 0.8880
# Epoch 172/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2566 - accuracy: 0.8880
# Epoch 173/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2567 - accuracy: 0.8819
# Epoch 174/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2549 - accuracy: 0.8798
# Epoch 175/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2539 - accuracy: 0.8798
# Epoch 176/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2525 - accuracy: 0.8819
# Epoch 177/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2517 - accuracy: 0.8839
# Epoch 178/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2516 - accuracy: 0.8819
# Epoch 179/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2498 - accuracy: 0.8819
# Epoch 180/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2484 - accuracy: 0.8921
# Epoch 181/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2483 - accuracy: 0.8819
# Epoch 182/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2480 - accuracy: 0.8819
# Epoch 183/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2444 - accuracy: 0.8880
# Epoch 184/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2441 - accuracy: 0.8921
# Epoch 185/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2443 - accuracy: 0.8880
# Epoch 186/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2420 - accuracy: 0.8900
# Epoch 187/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2428 - accuracy: 0.8819
# Epoch 188/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2410 - accuracy: 0.8921
# Epoch 189/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2401 - accuracy: 0.8961
# Epoch 190/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2393 - accuracy: 0.8961
# Epoch 191/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2395 - accuracy: 0.8921
# Epoch 192/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2372 - accuracy: 0.8941
# Epoch 193/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2355 - accuracy: 0.8961
# Epoch 194/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2347 - accuracy: 0.8982
# Epoch 195/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2338 - accuracy: 0.8961
# Epoch 196/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2350 - accuracy: 0.8941
# Epoch 197/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2324 - accuracy: 0.8941
# Epoch 198/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2327 - accuracy: 0.8982
# Epoch 199/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2300 - accuracy: 0.8982
# Epoch 200/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2328 - accuracy: 0.8941

# %%
scores = model.evaluate(X_train,y_train)
print("Training Accuracy: %.2f%%\n" % (scores[1]*100))
scores = model.evaluate(X_test,y_test)
print("Testing Accuracy: %.2f%%\n" % (scores[1]*100))
# Out:
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2270 - accuracy: 0.9002
# Training Accuracy: 90.02%
#
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5639 - accuracy: 0.7857
# Testing Accuracy: 78.57%

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
y_test_pred = np.argmax(model.predict(X_test),axis=1)
c_matrix = confusion_matrix(y_test,y_test_pred)
ax = sns.heatmap(c_matrix, annot=True, xticklabels=['No Diabetes','Diabetes'], yticklabels=['No Diabetes','Diabetes'], cbar= False, cmap='Blues')
ax.set_xlabel("Prediction")
ax.set_ylabel("Actual")
# Out:
# 5/5 [==============================] - 0s 3ms/step
# Text(50.72222222222221, 0.5, 'Actual')

# %%
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

y_test_pred_probs = model.predict(X_test)
FPR,TPR, _= roc_curve(y_test,y_test_pred_probs)
# Out:
# 5/5 [==============================] - 0s 4ms/step

# %%
plt.plot(FPR,TPR)
plt.plot([0,1],[0,1],'--',color='black')#diagonal line

plt.xlabel('False Positive Rate')

plt.ylabel('True Positive Rate')
# Out:
# Text(0, 0.5, 'True Positive Rate')
