# %% [markdown]
# # Problem Statement

# %% [markdown]
# - This dataset is created for prediction of the S&P 500 stock index based on interest rates and employment numbers.

# %% [markdown]
# # Step#0: Libraries Import

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Step#1: Import Dataset

# %%
stock=pd.read_csv(r'C:\Users\mmanasanjani\Desktop\Extra\MK\ML-Regression\ML Regression Course Package\6. Multiple Linear Regression\S&P500_Stock_Data.csv')

# %%
stock
# Out:
#      Interest Rates  Employment  S&P 500 Price
# 0          1.943859   55.413571    2206.680582
# 1          2.258229   59.546305    2486.474488
# 2          2.215863   57.414687    2405.868337
# 3          1.977960   49.908353    2140.434475
# 4          2.437723   52.035492    2411.275663
# ..              ...         ...            ...
# 995        2.528420   52.390828    2578.699184
# 996        2.643571   54.626204    2573.865933
# 997        2.009644   57.004357    2004.911218
# 998        2.201656   62.447790    2344.098981
# 999        2.180638   46.297034    2156.133786
#
# [1000 rows x 3 columns]

# %%
stock.head()
# Out:
#    Interest Rates  Employment  S&P 500 Price
# 0        1.943859   55.413571    2206.680582
# 1        2.258229   59.546305    2486.474488
# 2        2.215863   57.414687    2405.868337
# 3        1.977960   49.908353    2140.434475
# 4        2.437723   52.035492    2411.275663

# %%
stock.tail(10)
# Out:
#      Interest Rates  Employment  S&P 500 Price
# 990        2.018200   56.929616    2206.946180
# 991        1.936748   52.967524    2086.159182
# 992        2.591529   57.281030    2686.211789
# 993        1.740441   55.098645    1922.893274
# 994        1.868835   60.543377    2065.424594
# 995        2.528420   52.390828    2578.699184
# 996        2.643571   54.626204    2573.865933
# 997        2.009644   57.004357    2004.911218
# 998        2.201656   62.447790    2344.098981
# 999        2.180638   46.297034    2156.133786

# %%
stock.describe()
# Out:
#        Interest Rates   Employment  S&P 500 Price
# count     1000.000000  1000.000000    1000.000000
# mean         2.195392    56.254855    2319.999936
# std          0.241630     4.862178     193.854745
# min          1.500000    40.000000    1800.000000
# 25%          2.035735    53.029784    2190.447901
# 50%          2.198214    56.160941    2312.443024
# 75%          2.359061    59.422633    2455.764328
# max          3.000000    70.000000    3000.000000

# %%
stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Interest Rates  1000 non-null   float64
#  1   Employment      1000 non-null   float64
#  2   S&P 500 Price   1000 non-null   float64
# dtypes: float64(3)
# memory usage: 23.6 KB

# %% [markdown]
# # Step#2: Data Visualization

# %%
sns.jointplot(x='Employment',y='S&P 500 Price',data=stock)

# %%
sns.jointplot(x='Interest Rates',y='S&P 500 Price',data=stock)

# %%
sns.pairplot(stock)

# %% [markdown]
# # Step#3: Create Training and Testing Dataset/Data Cleaning

# %%
y=stock['S&P 500 Price']

# %%
y
# Out:
# 0      2206.680582
# 1      2486.474488
# 2      2405.868337
# 3      2140.434475
# 4      2411.275663
#           ...
# 995    2578.699184
# 996    2573.865933
# 997    2004.911218
# 998    2344.098981
# 999    2156.133786
# Name: S&P 500 Price, Length: 1000, dtype: float64

# %%
X = stock[['Interest Rates', 'Employment']]

# %%
X
# Out:
#      Interest Rates  Employment
# 0          1.943859   55.413571
# 1          2.258229   59.546305
# 2          2.215863   57.414687
# 3          1.977960   49.908353
# 4          2.437723   52.035492
# ..              ...         ...
# 995        2.528420   52.390828
# 996        2.643571   54.626204
# 997        2.009644   57.004357
# 998        2.201656   62.447790
# 999        2.180638   46.297034
#
# [1000 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

# %%
X_train
# Out:
#      Interest Rates  Employment
# 691        1.954949   52.746520
# 475        1.884734   52.994827
# 290        1.981246   51.365630
# 296        2.534132   55.371026
# 44         2.378293   53.868251
# ..              ...         ...
# 544        2.058277   56.643106
# 189        2.209058   55.241508
# 822        1.747157   57.161724
# 83         2.124967   64.268831
# 153        2.512355   56.317313
#
# [700 rows x 2 columns]

# %%
y_train
# Out:
# 691    2063.897571
# 475    2149.236151
# 290    2009.165061
# 296    2527.753296
# 44     2330.264882
#           ...
# 544    2245.261305
# 189    2348.810172
# 822    2056.535955
# 83     2265.169285
# 153    2569.794605
# Name: S&P 500 Price, Length: 700, dtype: float64

# %%
X_test
# Out:
#      Interest Rates  Employment
# 651        2.070113   60.347831
# 426        1.948948   54.266803
# 721        2.548241   47.863262
# 690        2.040708   51.236550
# 429        2.217774   53.495800
# ..              ...         ...
# 779        2.356679   63.277068
# 191        2.092564   60.854771
# 352        1.943041   50.299105
# 746        1.746800   58.477594
# 152        2.091777   57.487125
#
# [300 rows x 2 columns]

# %%
y_test
# Out:
# 651    2330.971718
# 426    2050.116370
# 721    2447.600914
# 690    2142.848999
# 429    2241.830339
#           ...
# 779    2530.399462
# 191    2339.592860
# 352    1967.949728
# 746    2134.279361
# 152    2214.110293
# Name: S&P 500 Price, Length: 300, dtype: float64

# %% [markdown]
# # Step#4: Training the Model

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression(fit_intercept = True)
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print('Linear Model Coefficients (m)', regressor.coef_)
print('Linear Model Coefficients (b)', regressor.intercept_)
# Out:
# Linear Model Coefficients (m) [725.27412502  12.43876068]
# Linear Model Coefficients (b) 26.676710028439174

# %% [markdown]
# # Step#5: Evaluating the Model

# %%
y_predict = regressor.predict(X_test)
y_predict
# Out:
# array([2278.72858839, 2115.21037817, 2470.20990245, 2144.06874537,
#        2300.59196614, 2193.38616885, 2106.43374469, 2482.85011514,
#        2257.57475335, 2308.30700101, 2113.51674248, 2408.96819024,
#        2519.92229426, 2484.68870678, 2199.9532173 , 2275.90507604,
#        2179.24543027, 2214.97887999, 2355.94496108, 2228.05769477,
#        2489.53916635, 1847.88205015, 2328.91719412, 2194.62441783,
#        2399.76679154, 2211.7131219 , 2158.14769102, 2052.97217399,
#        2268.5310165 , 2626.50335978, 2512.15158781, 2357.593316  ,
#        2274.38453735, 2010.88151226, 2361.17538042, 2586.46060255,
#        2145.31255277, 2471.99008693, 2205.43978186, 2570.1544482 ,
#        2317.91234938, 2224.85687479, 2472.76877541, 2525.27040443,
#        2104.39281242, 2222.79837483, 2236.70927706, 2630.39773875,
#        2146.53196077, 2695.10146774, 2610.93586409, 1987.34222448,
#        2237.84904199, 2314.22203138, 2231.06979885, 2548.21606742,
#        2518.64298032, 2647.71864721, 2432.66364933, 2509.76559093,
#        2511.17548293, 2233.95045905, 1861.45562631, 1955.37566617,
#        2125.01326307, 2218.65546782, 2363.80116912, 2086.49697976,
#        2216.53810307, 2483.88613499, 2487.94983459, 2188.28457048,
#        2315.71039049, 2176.96073331, 2531.6865463 , 2486.14334792,
#        2249.29667541, 2417.35010443, 2344.11572711, 2144.71945001,
#        2280.88753633, 2282.12055948, 2114.84414051, 2211.99861757,
#        2490.77285877, 2327.01760115, 2473.96084731, 2488.69171641,
#        2186.43419309, 2482.95340584, 2301.00625032, 2193.22513892,
#        2316.23876013, 2107.50562061, 2251.35035138, 2343.58248603,
#        2334.11447618, 2387.12948429, 1970.99941055, 2437.11111067,
#        2552.43602178, 2573.08064539, 2099.61736098, 2523.00295269,
#        2301.31717554, 2061.57240011, 2020.97438509, 2258.85734653])

# %%
y_test
# Out:
# 651    2330.971718
# 426    2050.116370
# 721    2447.600914
# 690    2142.848999
# 429    2241.830339
#           ...
# 779    2530.399462
# 191    2339.592860
# 352    1967.949728
# 746    2134.279361
# 152    2214.110293
# Name: S&P 500 Price, Length: 300, dtype: float64

# %%
plt.scatter(y_test, y_predict, color = 'g')
plt.ylabel('Model Predictions')
plt.xlabel('True Values (Ground Truth)')
plt.title('Multiple Linear Regression Predictions')
# Out:
# Text(0.5, 1.0, 'Multiple Linear Regression Predictions')

# %%
k = X_test.shape[1]
n = len(X_test)

# %%
n
# Out:
# 300

# %%
k
# Out:
# 2

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from math import sqrt

RMSE = float(format(np.sqrt(mean_squared_error(y_test, y_predict)) , '.3f'))
MSE = mean_squared_error(y_test, y_predict)
MAE = mean_absolute_error(y_test, y_predict)
r2 = r2_score(y_test, y_predict)
adj_r2 = 1-(1-r2) * (n-1)/(n-k-1)
MAPE = np.mean( np.abs( (y_test-y_predict) / y_test  )  )*100

# %%
print('RMSE = ', RMSE, '\nMSE =', MSE , '\nMAE =', MAE, '\nR2 =', r2, '\nAdjusted R2 =', adj_r2, '\nMAPE =', MAPE)
# Out:
# RMSE =  60.807
# MSE = 3697.4702310528614
# MAE = 48.41835045618344
# R2 = 0.8959014694639837
# Adjusted R2 = 0.895200469258354
# MAPE = 2.0848964265666443

# %% [markdown]
# # Step#6: Visualizing the Results

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
x_surf, y_surf = np.meshgrid( np.linspace( stock['Interest Rates'].min(), stock['Interest Rates'].max(), 100),  np.linspace(stock['Employment'].min(), stock['Employment'].max() , 100))

# %%
x_surf.shape
# Out:
# (100, 100)

# %%
onlyX = pd.DataFrame( {'Interest Rates': x_surf.ravel(), 'Employment':y_surf.ravel()    } )

# %%
onlyX.shape
# Out:
# (10000, 2)

# %%
fittedY = regressor.predict(onlyX)

# %%
fittedY.shape
# Out:
# (10000,)

# %%
fittedY = fittedY.reshape(x_surf.shape)

# %%
fittedY.shape
# Out:
# (100, 100)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')
ax.scatter( stock['Interest Rates'], stock['Employment'] , stock['S&P 500 Price'] , c = 'blue', marker ='x'  )
ax.plot_surface(x_surf, y_surf, fittedY, color = 'red', alpha = 0.3)
ax.set_xlabel('Interest Rates')
ax.set_ylabel('Unemployment Rates')
ax.set_zlabel('Stock index price')
# Out:
# Text(0.5, 0, 'Stock index price')

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(stock['Interest Rates'],stock['Employment'],stock['S&P 500 Price'],c='blue', marker='x', alpha=1)
ax.plot_surface(x_surf, y_surf, fittedY, color='red', alpha=0.3)
ax.set_xlabel('Interest_Rate')
ax.set_ylabel('Unemployment_Rate')
ax.set_zlabel('Stock_Index_Price')
ax.view_init(60, 70)
plt.show()

# %%
coeff_df = pd.DataFrame(regressor.coef_, X.columns, columns = ['Coefficient'])
coeff_df
# Out:
#                 Coefficient
# Interest Rates   725.274125
# Employment        12.438761
