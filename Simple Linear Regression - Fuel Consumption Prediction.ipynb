# %% [markdown]
# # Problem Statement

# %% [markdown]
# - You have been hired as a consultant to a major Automotive Manufacturer and you have been tasked to develop a model to predict the impact of increasing the vehicle horsepower (HP) on fuel economy (Mileage Per Gallon (MPG)). You gathered the data:
# - Data set:
#     - Independant variable X: Vehicle Horse Power
#     - Dependant variable Y: Mileage Per Gallon (MPG)

# %% [markdown]
# # Step#1: Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Step#2: Importing Dataset

# %%
fuel_economy_df=pd.read_csv(r'C:\Users\mmanasanjani\Desktop\Extra\MK\ML-Regression\ML Regression Course Package\3. Simple Linear Regression\FuelEconomy.csv')

# %%
fuel_economy_df
# Out:
#     Horse Power  Fuel Economy (MPG)
# 0    118.770799           29.344195
# 1    176.326567           24.695934
# 2    219.262465           23.952010
# 3    187.310009           23.384546
# 4    218.594340           23.426739
# ..          ...                 ...
# 95   162.810542           27.418661
# 96   266.869640           15.989945
# 97   243.831211           19.253375
# 98   140.959803           29.515593
# 99   184.123053           25.196097
#
# [100 rows x 2 columns]

# %%
fuel_economy_df.head()
# Out:
#    Horse Power  Fuel Economy (MPG)
# 0   118.770799           29.344195
# 1   176.326567           24.695934
# 2   219.262465           23.952010
# 3   187.310009           23.384546
# 4   218.594340           23.426739

# %%
fuel_economy_df.tail()
# Out:
#     Horse Power  Fuel Economy (MPG)
# 95   162.810542           27.418661
# 96   266.869640           15.989945
# 97   243.831211           19.253375
# 98   140.959803           29.515593
# 99   184.123053           25.196097

# %%
fuel_economy_df.describe()
# Out:
#        Horse Power  Fuel Economy (MPG)
# count   100.000000          100.000000
# mean    213.676190           23.178501
# std      62.061726            4.701666
# min      50.000000           10.000000
# 25%     174.996514           20.439516
# 50%     218.928402           23.143192
# 75%     251.706476           26.089933
# max     350.000000           35.000000

# %%
fuel_economy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Horse Power         100 non-null    float64
#  1   Fuel Economy (MPG)  100 non-null    float64
# dtypes: float64(2)
# memory usage: 1.7 KB

# %% [markdown]
# # Step#3: Visualizing the Dataset

# %%
fuel_economy_df.head(4)
# Out:
#    Horse Power  Fuel Economy (MPG)
# 0   118.770799           29.344195
# 1   176.326567           24.695934
# 2   219.262465           23.952010
# 3   187.310009           23.384546

# %%
sns.jointplot(x = 'Horse Power', y = 'Fuel Economy (MPG)', data = fuel_economy_df,color='green')

# %%
sns.jointplot(x = 'Fuel Economy (MPG)', y = 'Horse Power', data = fuel_economy_df,color='violet')

# %%
sns.pairplot(fuel_economy_df)

# %%
sns.lmplot(x = 'Horse Power', y =  'Fuel Economy (MPG)', data = fuel_economy_df)

# %%
sns.lmplot(x =  'Fuel Economy (MPG)',y = 'Horse Power', data = fuel_economy_df)

# %% [markdown]
# # Step#5: Create Training and Testing Data

# %%
X=fuel_economy_df[['Horse Power']] #df[[]] 2 []

# %%
y=fuel_economy_df[['Fuel Economy (MPG)']]

# %%
X.shape
# Out:
# (100, 1)

# %%
y.shape
# Out:
# (100, 1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3)

# %%
X_train.shape
# Out:
# (70, 1)

# %%
X_test.shape
# Out:
# (30, 1)

# %%
y_train.shape
# Out:
# (70, 1)

# %%
y_test.shape
# Out:
# (30, 1)

# %% [markdown]
# # Step#5: Training the Model

# %%
X_train.shape
# Out:
# (70, 1)

# %%
X_test.shape
# Out:
# (30, 1)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression(fit_intercept=True) #include intercept also, if false, passes through origin

# %%
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print('Linear Model Coeff (m):', regressor.coef_)
print('Linear Model Coeff (b):', regressor.intercept_)
# Out:
# Linear Model Coeff (m): [[-0.07056953]]
# Linear Model Coeff (b): [38.22761146]

# %%
# checking for intercept=False
from sklearn.linear_model import LinearRegression
regressor=LinearRegression(fit_intercept=False) #include intercept also, if false, passes through origin
regressor.fit(X_train,y_train)
# Out:
# LinearRegression(fit_intercept=False)

# %%
print('Linear Model Coeff (m):', regressor.coef_)
print('Linear Model Coeff (b):', regressor.intercept_) #with intercept=False, slope became positive, which ideally isn't
# Out:
# Linear Model Coeff (m): [[0.09398597]]
# Linear Model Coeff (b): 0.0

# %% [markdown]
# # Step#6: Test the Model

# %%
y_predict=regressor.predict(X_test)

# %%
y_predict
# Out:
# array([[23.99892698],
#        [18.28436268],
#        [19.99073554],
#        [23.21472335],
#        [32.25940573],
#        [20.88018097],
#        [20.98335811],
#        [20.40510835],
#        [27.26002205],
#        [30.72906559],
#        [22.181503  ],
#        [19.9741055 ],
#        [21.53285518],
#        [21.0546693 ],
#        [21.0271889 ],
#        [28.28014447],
#        [14.81979761],
#        [25.44973251],
#        [19.39474648],
#        [19.99891298],
#        [25.8088407 ],
#        [29.32095996],
#        [19.8319385 ],
#        [21.82372794],
#        [31.77471503],
#        [26.04422946],
#        [26.73814809],
#        [16.98235941],
#        [25.00923221],
#        [22.39589648]])

# %%
y_test
# Out:
#     Fuel Economy (MPG)
# 58           22.937653
# 33           15.676316
# 26           21.167343
# 20           23.204745
# 67           34.114025
# 52           22.849711
# 47           19.536770
# 39           20.407571
# 12           27.294930
# 87           31.722566
# 92           24.181109
# 78           20.470676
# 16           23.185280
# 24           21.623369
# 42           21.442703
# 98           29.515593
# 86           15.837968
# 65           25.575084
# 96           15.989945
# 74           21.261778
# 31           26.188478
# 8            28.718210
# 94           17.802706
# 21           22.313051
# 28           31.806706
# 41           27.387012
# 95           27.418661
# 35           15.725650
# 3            23.384546
# 84           21.701202

# %%
#plotting training data - 70 samples
plt.scatter(X_train, y_train, color = 'orange')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.xlabel('Horse Power (HP)')
plt.ylabel('MPG')
plt.title('HP vs. MPG (Training Set)')
# Out:
# Text(0.5, 1.0, 'HP vs. MPG (Training Set)')

# %%
#plotting the test data--> shows 30 samples
plt.scatter(X_test, y_test, color = 'green')
plt.plot(X_test, regressor.predict(X_test), color = 'blue')
plt.xlabel('Horse Power (HP)')
plt.ylabel('MPG')
plt.title('HP vs. MPG (Training Set)')
# Out:
# Text(0.5, 1.0, 'HP vs. MPG (Training Set)')

# %%
#Prediction for random values
HP=[150]
#MPG(Mileage per gallon)=??
MPG=regressor.predict([HP])
# Out:
# C:\Users\mmanasanjani\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
MPG
# Out:
# array([[27.64218199]])

# %%
HP=[100]
MPG=regressor.predict([HP])
MPG
# Out:
# C:\Users\mmanasanjani\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[31.17065848]])

# %%
HP=[300]
MPG=regressor.predict([HP])
MPG
# Out:
# C:\Users\mmanasanjani\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[17.05675252]])

# %%
HP=[500] #extrapolating the data
MPG=regressor.predict([HP])
MPG
# Out:
# C:\Users\mmanasanjani\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[2.94284657]])
